# %% [markdown]
# # TheTanti AI Generation Backend\nRun these cells on a Kaggle GPU notebook. Keep ComfyUI private; expose only FastAPI when tunneling is required.

# %%
# !python -m pip install -r thetanti-ai/requirements.txt\n

# %%
# !bash thetanti-ai/scripts/install_comfyui.sh\n

# %%
# !bash thetanti-ai/scripts/install_models.sh\n

# %%
import os\nos.environ['THE_TANTI_API_KEY'] = os.environ.get('THE_TANTI_API_KEY', 'change-me')\nos.environ['MOCK_GENERATION'] = 'false'\nos.environ['COMFYUI_ENABLED'] = 'true'\n

# %%
# Start ComfyUI in one background process, then the API in another.\n# Use Kaggle output logs to verify both services before tunneling FastAPI only.\n
